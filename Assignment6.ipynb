# %%
data = pd.read_csv('myJobData.csv')
data
# Out:
#     experience  written_score  interview_score  salary
# 0           12             98               90   20000
# 1            2             90               78    8000
# 2            3             85               85   12000
# 3            4             78               88   15000
# 4            5             92               75   18000
# 5            6             80               82   11000
# 6            7             72               90   14000
# 7            8             95               83   22000
# 8            9             88               72   13000
# 9           10             82               92   16000
# 10          11             75               80   10000
# 11          12             90               87   19000
# 12          13             83               78   14000
# 13          14             78               85   17000
# 14          15             92               72   12000
# 15          16             85               88   15000
# ...

# %%
# Separate features and target variable
features = ["experience", "written_score", "interview_score"]
target = "salary"
X = data[features]
y = data[target]

# %%
# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
myModel = KNeighborsRegressor(n_neighbors=3)
# n_neighbors is the value of K nearest neighbours

# %%
myModel.fit(X_train, y_train)
# Out:
# KNeighborsRegressor(n_neighbors=2)

# %%
person_a = [5, 80, 90]  # 5 years experience, 80 written score, 90 interview score
person_b = [8, 70, 60]  # 8 years experience, 70 written score, 60 interview score

# %%
salary_a = myModel.predict([person_a])[0]
salary_b = myModel.predict([person_b])[0]
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but KNeighborsRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but KNeighborsRegressor was fitted with feature names
#   warnings.warn(

# %%
print("Salary of a : {}".format(salary_a))
print("Salary of b : {}".format(salary_b))
# Out:
# Salary of a : 15500.0
# Salary of b : 11500.0

# %% [markdown]
# 2 Create a dataset (.csv file) having following features- Graduations percentage,
# experience of the candidate, written score, interview score and selection. Selection
# feature is binary in nature and contains the status of the candidate. Also store at least
# 25 records in this dataset.
# Using this data, build a Bayesian learning model for HR department that can help
# them to decide whether the candidate will be selected or not. Take 80% data as
# training data and remaining a testing data randomly. Using the built model, predict
# the status for the following unseen data:
# (a) 90 %, 5 Yrs experience, 8 written test score, 10 interview score
# (b) 75%, 8 Yrs experience, 7 written test score, 6 interview score
# Also calculate the possible classification metrics for the above cases and save these
# values in the .CSV file.

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

# %%
data = pd.read_csv('myJobData2.csv')
data
# Out:
#     graduation_percentage  experience  written_score  interview_score  \
# 0                   78.54           3              8                7
# 1                   84.21           2              9                8
# 2                   72.98           5              7                6
# 3                   87.14           8              9               10
# 4                   91.37           1              8                9
# 5                   82.78           4              6                7
# 6                   70.12           7              5                5
# 7                   90.45           6             10                9
# 8                   81.89           9              7                8
# 9                   75.63           2              8                7
# 10                  89.96           5              9                9
# 11                  73.27           8              6                5
# ...

# %%
features = ["graduation_percentage","experience", "written_score", "interview_score"]
target = "selection"
X = data[features]
y = data[target]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
myModel = GaussianNB()
myModel.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
predictions = myModel.predict(X_test)

accuracy_test = accuracy_score(y_test, predictions)
precision_test = precision_score(y_test, predictions)
recall_test = recall_score(y_test, predictions)

print("Accuracy of my model : {}%".format(int(accuracy*100)))
print("Precision of my model : {}%".format(int(precision*100)))
print("Recall of my model : {}%".format(int(recall*100)))
# Out:
# Accuracy of my model : 95%
# Precision of my model : 95%
# Recall of my model : 95%

# %%
person_a = [90, 5, 8, 10]  # 90 %, 5 Yrs experience, 8 written test score, 10 interview score
person_b = [75, 8, 7, 6]  # 75%, 8 Yrs experience, 7 written test score, 6 interview score

pred_a = myModel.predict([person_a])[0]
pred_b = myModel.predict([person_b])[0]

if pred_a:
  print("a will get the job")
else:
  print("a will not get the job")

if pred_b:
  print("b will get the job")
else:
  print("b will not get the job")
# Out:
# a will get the job
# b will not get the job
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(

# %% [markdown]
# 3 For the IRIS dataset, design a decision tree classifier. Take different percentage of
# training data and then observe effect on the accuracy and other quality parameters.
# Also note the effect of other decision tree parameters (like max depth,
# min_sample_spit etc.) on the performance of the model.
# Note: Take criterion as entropy.

# %%
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score

iris = load_iris()
X = iris.data  # Features
y = iris.target  # Target labels

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.8)

# %%
myModel = DecisionTreeClassifier(criterion="entropy")

# %%
myModel.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
y_pred = myModel.predict(X_test)

# %%
# Evaluate performance
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average="weighted")
recall = recall_score(y_test, y_pred, average="weighted")

print("Accuracy of my model : {}%".format(int(accuracy*100)))
print("Precision of my model : {}%".format(int(precision*100)))
print("Recall of my model : {}%".format(int(recall*100)))
# Out:
# Accuracy of my model : 95%
# Precision of my model : 95%
# Recall of my model : 95%

# %% [markdown]
# 4 By taking Classified Data as input, compare the performance of KNN, Bayesian
# Classifier and Decision Tree model. In this comparison, you can take different
# possible parameters of particular model. Save these output in a .csv file.

# %%
# testing all 3 on myJobData2.csv
data = pd.read_csv('myJobData2.csv')
data
# Out:
#     graduation_percentage  experience  written_score  interview_score  \
# 0                   78.54           3              8                7
# 1                   84.21           2              9                8
# 2                   72.98           5              7                6
# 3                   87.14           8              9               10
# 4                   91.37           1              8                9
# 5                   82.78           4              6                7
# 6                   70.12           7              5                5
# 7                   90.45           6             10                9
# 8                   81.89           9              7                8
# 9                   75.63           2              8                7
# 10                  89.96           5              9                9
# 11                  73.27           8              6                5
# ...

# %%
features = ["graduation_percentage","experience", "written_score", "interview_score"]
target = "selection"
X = data[features]
y = data[target]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
myModel_NB = GaussianNB()
myModel_DT = DecisionTreeClassifier(criterion="entropy")
myModel_KNN = KNeighborsRegressor(n_neighbors=3)

myModel_NB.fit(X_train, y_train)
myModel_DT.fit(X_train, y_train)
myModel_KNN.fit(X_train, y_train)
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
predictions_NB = myModel_NB.predict(X_test)
predictions_DT = myModel_DT.predict(X_test)
predictions_KNN = myModel_KNN.predict(X_test)

accuracy_test_NB = accuracy_score(y_test, predictions_NB)
accuracy_test_DT = accuracy_score(y_test, predictions_DT)
accuracy_test_KNN = accuracy_score(y_test, predictions_KNN)

precision_test_NB = precision_score(y_test, predictions_NB)
precision_test_DT = precision_score(y_test, predictions_DT)
precision_test_KNN = precision_score(y_test, predictions_KNN)

# recall_test = recall_score(y_test, predictions)

print("Accuracy of my NB model : {}%".format(int(accuracy_test_NB*100)))
# print("Precision of my model : {}%".format(int(precision*100)))
# print("Recall of my model : {}%".format(int(recall*100)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-87-8434ed2feb1c> in <cell line: 7>()
#       5 accuracy_test_NB = accuracy_score(y_test, predictions_NB)
#       6 accuracy_test_DT = accuracy_score(y_test, predictions_DT)
# ----> 7 accuracy_test_KNN = accuracy_score(y_test, predictions_KNN)
#       8
#       9 precision_test_NB = precision_score(y_test, predictions_NB)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     190
#     191             try:
# --> 192                 return func(*args, **kwargs)
#     193             except InvalidParameterError as e:
#     194                 # When the function is just a wrapper around an estimator, we allow
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     219
# ...
